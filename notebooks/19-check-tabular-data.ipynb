# %%
import pandas as pd
import glob, os
import numpy as np
import matplotlib.pyplot as plt

# %%
data_dir = '/glade/derecho/scratch/joko/synth-ros/params_200_50-debug-20250316/tabular-data'
# Use glob to find all .txt files in the directory
file_paths = glob.glob(f"{data_dir}/*.txt")

# Read all the files into a list of DataFrames and concatenate them
df = pd.concat([pd.read_csv(file, header=None) for file in file_paths], ignore_index=True)

# Display the final DataFrame
df.head()
# Out:
#            0      1   2          3          4         5         6         7   \
# 0  027094_033  27094  33  12.159344  53.623666  0.834664  1.095021  0.859896
# 1  027094_040  27094  40  12.159344  53.623666  0.834664  1.095021  0.859896
# 2  027094_042  27094  42  12.159344  53.623666  0.834664  1.095021  0.859896
# 3  027094_049  27094  49  12.159344  53.623666  0.834664  1.095021  0.859896
# 4  027094_065  27094  65  12.159344  53.623666  0.834664  1.095021  0.859896
#
#     8             9   ...        11        12        13        14         15  \
# 0  6.0  53965.807545  ...  0.258224  0.030386  0.660237  0.622506  26.098072
# 1  6.0  53965.807545  ...  0.258224  0.030386  0.770407  0.604525  30.833221
# 2  6.0  53965.807545  ...  0.258224  0.030386  0.842644  0.882819  27.959513
# 3  6.0  53965.807545  ...  0.258224  0.030386  0.720721  0.465052  25.366994
# 4  6.0  53965.807545  ...  0.258224  0.030386  0.866447  0.737889  28.049064
#
#        16          17        18        19        20
# 0  1488.0  378.333041  0.276620  0.802343  0.130636
# 1  1607.5  411.771640  0.262407  0.814924  0.119137
# 2  1457.0  382.132030  0.271003  0.808334  0.125384
# 3  1240.0  305.847763  0.275121  0.747274  0.166579
# 4  1269.0  318.509666  0.225787  0.736751  0.157190
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (7000000, 21)

# %%
colnames = ['unique_id', 'ros_id', 'proj_id', 'a', 'c', 
            'f_r0', 'f_hp', 'f_h0', 'n_arms', 'sa', 'vol', 
            'sa_eff', 'rho_eff', 'aspect_ratio', 'aspect_ratio_elip', 
            'extreme_pts', 'contour_area', 'contour_perimeter', 
            'area_ratio', 'complexity', 'circularity']
df.columns = colnames

# %%
df.head()
# Out:
#     unique_id  ros_id  proj_id          a          c      f_r0      f_hp  \
# 0  027094_033   27094       33  12.159344  53.623666  0.834664  1.095021
# 1  027094_040   27094       40  12.159344  53.623666  0.834664  1.095021
# 2  027094_042   27094       42  12.159344  53.623666  0.834664  1.095021
# 3  027094_049   27094       49  12.159344  53.623666  0.834664  1.095021
# 4  027094_065   27094       65  12.159344  53.623666  0.834664  1.095021
#
#        f_h0  n_arms            sa  ...    sa_eff   rho_eff  aspect_ratio  \
# 0  0.859896     6.0  53965.807545  ...  0.258224  0.030386      0.660237
# 1  0.859896     6.0  53965.807545  ...  0.258224  0.030386      0.770407
# 2  0.859896     6.0  53965.807545  ...  0.258224  0.030386      0.842644
# 3  0.859896     6.0  53965.807545  ...  0.258224  0.030386      0.720721
# 4  0.859896     6.0  53965.807545  ...  0.258224  0.030386      0.866447
#
#    aspect_ratio_elip  extreme_pts  contour_area  contour_perimeter  \
# 0           0.622506    26.098072        1488.0         378.333041
# 1           0.604525    30.833221        1607.5         411.771640
# 2           0.882819    27.959513        1457.0         382.132030
# 3           0.465052    25.366994        1240.0         305.847763
# 4           0.737889    28.049064        1269.0         318.509666
#
#    area_ratio  complexity  circularity
# 0    0.276620    0.802343     0.130636
# 1    0.262407    0.814924     0.119137
# 2    0.271003    0.808334     0.125384
# 3    0.275121    0.747274     0.166579
# 4    0.225787    0.736751     0.157190
#
# [5 rows x 21 columns]

# %%
# Save to CSV with header
csv_filename = 'ros-tabular-data.csv'
csv_save_path = os.path.join(data_dir, csv_filename)
df.to_csv(csv_save_path, header=True, index=False)

# %%
# test read CSV
df_test = pd.read_csv(csv_save_path)
df_test.head()
# Out:
#     unique_id  ros_id  proj_id          a          c      f_r0      f_hp  \
# 0  027094_033   27094       33  12.159344  53.623666  0.834664  1.095021
# 1  027094_040   27094       40  12.159344  53.623666  0.834664  1.095021
# 2  027094_042   27094       42  12.159344  53.623666  0.834664  1.095021
# 3  027094_049   27094       49  12.159344  53.623666  0.834664  1.095021
# 4  027094_065   27094       65  12.159344  53.623666  0.834664  1.095021
#
#        f_h0  n_arms            sa  ...    sa_eff   rho_eff  aspect_ratio  \
# 0  0.859896     6.0  53965.807545  ...  0.258224  0.030386      0.660237
# 1  0.859896     6.0  53965.807545  ...  0.258224  0.030386      0.770407
# 2  0.859896     6.0  53965.807545  ...  0.258224  0.030386      0.842644
# 3  0.859896     6.0  53965.807545  ...  0.258224  0.030386      0.720721
# 4  0.859896     6.0  53965.807545  ...  0.258224  0.030386      0.866447
#
#    aspect_ratio_elip  extreme_pts  contour_area  contour_perimeter  \
# 0           0.622506    26.098072        1488.0         378.333041
# 1           0.604525    30.833221        1607.5         411.771640
# 2           0.882819    27.959513        1457.0         382.132030
# 3           0.465052    25.366994        1240.0         305.847763
# 4           0.737889    28.049064        1269.0         318.509666
#
#    area_ratio  complexity  circularity
# 0    0.276620    0.802343     0.130636
# 1    0.262407    0.814924     0.119137
# 2    0.271003    0.808334     0.125384
# 3    0.275121    0.747274     0.166579
# 4    0.225787    0.736751     0.157190
#
# [5 rows x 21 columns]

# %%
# Save as parquet with header
pqt_filename = 'ros-tabular-data.parquet'
pqt_save_path = os.path.join(data_dir, pqt_filename)
df.to_parquet(pqt_save_path, index=False)

# %%
# test read parquet
df_pqt = pd.read_parquet(pqt_save_path)
df_pqt.head()
# Out:
#     unique_id  ros_id  proj_id          a          c      f_r0      f_hp  \
# 0  027094_033   27094       33  12.159344  53.623666  0.834664  1.095021
# 1  027094_040   27094       40  12.159344  53.623666  0.834664  1.095021
# 2  027094_042   27094       42  12.159344  53.623666  0.834664  1.095021
# 3  027094_049   27094       49  12.159344  53.623666  0.834664  1.095021
# 4  027094_065   27094       65  12.159344  53.623666  0.834664  1.095021
#
#        f_h0  n_arms            sa  ...    sa_eff   rho_eff  aspect_ratio  \
# 0  0.859896     6.0  53965.807545  ...  0.258224  0.030386      0.660237
# 1  0.859896     6.0  53965.807545  ...  0.258224  0.030386      0.770407
# 2  0.859896     6.0  53965.807545  ...  0.258224  0.030386      0.842644
# 3  0.859896     6.0  53965.807545  ...  0.258224  0.030386      0.720721
# 4  0.859896     6.0  53965.807545  ...  0.258224  0.030386      0.866447
#
#    aspect_ratio_elip  extreme_pts  contour_area  contour_perimeter  \
# 0           0.622506    26.098072        1488.0         378.333041
# 1           0.604525    30.833221        1607.5         411.771640
# 2           0.882819    27.959513        1457.0         382.132030
# 3           0.465052    25.366994        1240.0         305.847763
# 4           0.737889    28.049064        1269.0         318.509666
#
#    area_ratio  complexity  circularity
# 0    0.276620    0.802343     0.130636
# 1    0.262407    0.814924     0.119137
# 2    0.271003    0.808334     0.125384
# 3    0.275121    0.747274     0.166579
# 4    0.225787    0.736751     0.157190
#
# [5 rows x 21 columns]

# %%
print(pqt_save_path)
# Out:
# /glade/derecho/scratch/joko/synth-ros/params_200_50-debug-20250316/tabular-data/ros-tabular-data.parquet

# %%
df_pqt.shape
# Out:
# (7000000, 21)
